# %% [markdown]
# # HIP RDataFrame Demonstration 4: Loading multiple files and skimming
#
# In this demonstration we will go through:
# 1. How to load multiple files to a single RDF with TChain
# 2. How to skim the files by first filtering them and then saving the filtered RDF as a `.root` file
#
# -- Made by Nico Toikka

# %% [markdown]
# ## Initialization
#
# Import the only library you'll ever need.

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.30/04

# %% [markdown]
# ROOT and RDFs can automatically use multithreading. You can set it up with the following command, and if no number is specified ROOT will default to all threads that are available to it, so be careful!

# %%
ROOT.EnableImplicitMT(4)

# %% [markdown]
# ## Find the files and load the RDF
#
# We will use the same ZeroBias dataset from eos as in demonstration 2. With the Python module glob we can find all the `.root` files and create a list of them.

# %%
import glob

directory_path = '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/'

root_files = glob.glob(f'{directory_path}/**/*.root', recursive=True)

# Print the list of .root files
print(root_files)
# Out:
# ['/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/616/00000/5a510161-4c3e-4509-b1fc-0ee35fb5c493.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/648/00000/efcb2c35-f56e-4da9-994c-dcdc285d57fc.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/654/00000/11e7a7a6-a89f-46fb-8d8b-b65d545424ae.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/663/00000/d08ee08b-f37d-45bc-b987-4a184720d07e.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/664/00000/25aa2ec7-1ff4-437a-bc5f-53e7f59227d6.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/665/00000/9d62bf7e-dd07-47df-b246-b2caa019f169.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/666/00000/d46fa0c3-c716-4b9d-85fb-c92a4a43885a.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/667/00000/7380749c-5c23-42f0-b7f5-bc67e1ba6e70.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/694/00000/30d872ce-e478-4544-982e-fb6f1f57e97b.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/717/00000/357d6e29-075e-4979-a60f-03c6d95170b9.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/725/00000/2633554a-17a9-42e7-820e-5ffec3308876.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/725/00000/d5e23350-f788-4fe3-8bf3-cfdf53cb3a0d.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/68d1f9d7-5114-4214-a623-258efcf8ed5d.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/6a7afaca-4cbd-4024-926f-b0f8b1a0b54b.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/768e67bf-0a90-43b1-b6df-6e8904f3e008.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/ad32af44-134a-4e63-91ac-39069cbb85eb.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/e87145ee-3b6b-44a5-941d-0f44b00f192c.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/ee43fb94-f2c8-4aed-ae05-fe58bfc267e4.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/f4341d8e-6aa5-401b-8312-0a5992e5667c.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/750/00000/0cdcc612-bcef-4f5d-abde-c69f6df2b83c.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/751/00000/5ca6001a-9e84-4940-aa4c-b38f5db5ad68.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/753/00000/82959802-1716-41a6-9509-bc74f6365415.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/753/00000/b36e923d-868d-4516-b478-b1c837e928a9.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/0cdb595d-139d-4a8c-b977-b10d3690e474.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/7e2dd65f-ba87-40f7-a84a-f878377a8978.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/88c3bd03-f25b-420c-96a5-b9f554212ee0.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/b22ea534-d353-4314-9978-80b496a39e9b.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/c34d019e-e702-4e7f-acfe-421cf9aac8a4.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/774/00000/2bb51334-df91-4d94-a6f2-eb2b6f869588.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/775/00000/8999aecc-9bfe-4ba2-b711-414a7344c6d2.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/776/00000/128cf804-f9ee-4b7a-bcfd-5c76d612ed1b.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/776/00000/f644604a-72bc-4fb0-ab9a-4a832ee8a7a6.root', '/eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/00 ...

# %% [markdown]
# Now with the files in a list we can create a TChain from the Events trees in the files

# %%
tree = "Events"
chain = ROOT.TChain(tree)

for file in root_files:
    chain.Add(file)

print(f"Number of entries: {chain.GetEntries()}")
# Out:
# Number of entries: 7285827
# Warning in <TClass::Init>: no dictionary for class edm::Hash<1> is available
# Warning in <TClass::Init>: no dictionary for class edm::ParameterSetBlob is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessHistory is available
# Warning in <TClass::Init>: no dictionary for class edm::ProcessConfiguration is available
# Warning in <TClass::Init>: no dictionary for class pair<edm::Hash<1>,edm::ParameterSetBlob> is available

# %% [markdown]
# The TChain can be used directly to initialize the RDF.
#
# **Note** The TChain is from the programs point of view the "seed" of the RDF. If it goes out of scope for any reason, the RDF will cause a crash.

# %%
df = ROOT.RDataFrame(chain)
df.Describe()
# Out:
# Dataframe from TChain Events in files
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/616/00000/5a510161-4c3e-4509-b1fc-0ee35fb5c493.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/648/00000/efcb2c35-f56e-4da9-994c-dcdc285d57fc.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/654/00000/11e7a7a6-a89f-46fb-8d8b-b65d545424ae.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/663/00000/d08ee08b-f37d-45bc-b987-4a184720d07e.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/664/00000/25aa2ec7-1ff4-437a-bc5f-53e7f59227d6.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/665/00000/9d62bf7e-dd07-47df-b246-b2caa019f169.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/666/00000/d46fa0c3-c716-4b9d-85fb-c92a4a43885a.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/667/00000/7380749c-5c23-42f0-b7f5-bc67e1ba6e70.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/694/00000/30d872ce-e478-4544-982e-fb6f1f57e97b.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/717/00000/357d6e29-075e-4979-a60f-03c6d95170b9.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/725/00000/2633554a-17a9-42e7-820e-5ffec3308876.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/725/00000/d5e23350-f788-4fe3-8bf3-cfdf53cb3a0d.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/68d1f9d7-5114-4214-a623-258efcf8ed5d.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/6a7afaca-4cbd-4024-926f-b0f8b1a0b54b.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/768e67bf-0a90-43b1-b6df-6e8904f3e008.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/ad32af44-134a-4e63-91ac-39069cbb85eb.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/e87145ee-3b6b-44a5-941d-0f44b00f192c.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/ee43fb94-f2c8-4aed-ae05-fe58bfc267e4.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/749/00000/f4341d8e-6aa5-401b-8312-0a5992e5667c.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/750/00000/0cdcc612-bcef-4f5d-abde-c69f6df2b83c.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/751/00000/5ca6001a-9e84-4940-aa4c-b38f5db5ad68.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/753/00000/82959802-1716-41a6-9509-bc74f6365415.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/753/00000/b36e923d-868d-4516-b478-b1c837e928a9.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/0cdb595d-139d-4a8c-b977-b10d3690e474.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/7e2dd65f-ba87-40f7-a84a-f878377a8978.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/88c3bd03-f25b-420c-96a5-b9f554212ee0.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/b22ea534-d353-4314-9978-80b496a39e9b.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/772/00000/c34d019e-e702-4e7f-acfe-421cf9aac8a4.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/774/00000/2bb51334-df91-4d94-a6f2-eb2b6f869588.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/775/00000/8999aecc-9bfe-4ba2-b711-414a7344c6d2.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/776/00000/128cf804-f9ee-4b7a-bcfd-5c76d612ed1b.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/776/00000/f644604a-72bc-4fb0-ab9a-4a832ee8a7a6.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/370/790/00000/46658371-10b6-4e8c-8721-9a8e6e352a03.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/371/225/00000/517d9974-c4c9-4099-84c5-448b53c6feb7.root
#   /eos/cms/store/data/Run2023D/ZeroBias/NANOAOD/PromptReco-v2/000/371/227/00000/1c9355c5-1746-47b2-9aa8-4419a78e5c5e.root
#
# Property                Value
# --------                -----
# Columns in total         1048
# Columns from defines        0
# Event loops run             0
# Processing slots            4
#
# Column                                                          Type                            Origin
# ------                                                          ----                            ------
# BeamSpot_sigmaZ                                                 Float_t                         Dataset
# BeamSpot_sigmaZError                                            Float_t                         Dataset
# BeamSpot_type                                                   Char_t                          Dataset
# BeamSpot_z                                                      Float_t                         Dataset
# BeamSpot_zError                                                 Float_t                         Dataset
# CaloMET_phi                                                     Float_t                         Dataset
# CaloMET_pt                                                      Float_t                         Dataset
# CaloMET_sumEt                                                   Float_t                         Dataset
# ChsMET_phi                                                      Float_t                         Dataset
# ChsMET_pt                                                       Float_t                         Dataset
# ChsMET_sumEt                                                    Float_t                         Dataset
# CorrT1METJet_area                                               ROOT::VecOps::RVec<Float_t>     Dataset
# CorrT1METJet_eta                                                ROOT::VecOps::RVec<Float_t>     Dataset
# CorrT1METJet_muonSubtrFactor                                    ROOT::VecOps::RVec<Float_t>     Dataset
# CorrT1METJet_phi                                                ROOT::VecOps::RVec<Float_t>     Dataset
# CorrT1METJet_rawPt                                              ROOT::VecOps::RVec<Float_t>     Dataset
# DeepMETResolutionTune_phi                                       Float_t                         Dataset
# DeepMETResolutionTune_pt                                        Float_t                         Dataset
# DeepMETResponseTune_phi                                         Float_t                         Dataset
# DeepMETResponseTune_pt                                          Float_t                         Dataset
# Electron_charge                                                 ROOT::VecOps::RVec<Int_t>       Dataset
# Electron_convVeto                                               ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_cutBased                                               ROOT::VecOps::RVec<UChar_t>     Dataset
# Electron_cutBased_Fall17V2                                      ROOT::VecOps::RVec<UChar_t>     Dataset
# Electron_cutBased_HEEP                                          ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_deltaEtaSC                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dr03EcalRecHitSumEt                                    ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dr03HcalDepth1TowerSumEt                               ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dr03TkSumPt                                            ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dr03TkSumPtHEEP                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dxy                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dxyErr                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dz                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_dzErr                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_eInvMinusPInv                                          ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_energyErr                                              ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_eta                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_fsrPhotonIdx                                           ROOT::VecOps::RVec<Short_t>     Dataset
# Electron_hoe                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_ip3d                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_isPFcand                                               ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_jetIdx                                                 ROOT::VecOps::RVec<Short_t>     Dataset
# Electron_jetNDauCharged                                         ROOT::VecOps::RVec<UChar_t>     Dataset
# Electron_jetPtRelv2                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_jetRelIso                                              ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_jetRelIso_Fall17V2                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_lostHits                                               ROOT::VecOps::RVec<UChar_t>     Dataset
# Electron_mass                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_miniPFRelIso_all                                       ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_miniPFRelIso_all_Fall17V2                              ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_miniPFRelIso_chg                                       ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_miniPFRelIso_chg_Fall17V2                              ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_mvaHZZIso                                              ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_mvaIso                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_mvaIso_Fall17V2                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_mvaIso_Fall17V2_WP80                                   ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaIso_Fall17V2_WP90                                   ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaIso_Fall17V2_WPL                                    ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaIso_WP80                                            ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaIso_WP90                                            ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaNoIso                                               ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_mvaNoIso_Fall17V2                                      ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_mvaNoIso_Fall17V2_WP80                                 ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaNoIso_Fall17V2_WP90                                 ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaNoIso_Fall17V2_WPL                                  ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaNoIso_WP80                                          ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaNoIso_WP90                                          ROOT::VecOps::RVec<Bool_t>      Dataset
# Electron_mvaTTH                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_pdgId                                                  ROOT::VecOps::RVec<Int_t>       Dataset
# Electron_pfRelIso03_all                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_pfRelIso03_all_Fall17V2                                ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_pfRelIso03_chg                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_pfRelIso03_chg_Fall17V2                                ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_phi                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_photonIdx                                              ROOT::VecOps::RVec<Short_t>     Dataset
# Electron_pt                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_r9                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_scEtOverPt                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_seedGain                                               ROOT::VecOps::RVec<UChar_t>     Dataset
# Electron_seediEtaOriX                                           ROOT::VecOps::RVec<Char_t>      Dataset
# Electron_seediPhiOriY                                           ROOT::VecOps::RVec<Int_t>       Dataset
# Electron_sieie                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_sip3d                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Electron_svIdx                                                  ROOT::VecOps::RVec<Short_t>     Dataset
# Electron_tightCharge                                            ROOT::VecOps::RVec<UChar_t>     Dataset
# Electron_vidNestedWPBitmap                                      ROOT::VecOps::RVec<Int_t>       Dataset
# Electron_vidNestedWPBitmapHEEP                                  ROOT::VecOps::RVec<Int_t>       Dataset
# Electron_vidNestedWPBitmap_Fall17V2                             ROOT::VecOps::RVec<Int_t>       Dataset
# FatJet_area                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_btagDDBvLV2                                              ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_btagDDCvBV2                                              ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_btagDDCvLV2                                              ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_btagDeepB                                                ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_btagHbb                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_electronIdx3SJ                                           ROOT::VecOps::RVec<Short_t>     Dataset
# FatJet_eta                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_jetId                                                    ROOT::VecOps::RVec<UChar_t>     Dataset
# FatJet_lsf3                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_mass                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_msoftdrop                                                ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_muonIdx3SJ                                               ROOT::VecOps::RVec<Short_t>     Dataset
# FatJet_n2b1                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_n3b1                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_nConstituents                                            ROOT::VecOps::RVec<UChar_t>     Dataset
# FatJet_particleNetWithMass_H4qvsQCD                             ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNetWithMass_HbbvsQCD                             ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNetWithMass_HccvsQCD                             ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNetWithMass_QCD                                  ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNetWithMass_TvsQCD                               ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNetWithMass_WvsQCD                               ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNetWithMass_ZvsQCD                               ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_QCD                                          ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_QCD0HF                                       ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_QCD1HF                                       ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_QCD2HF                                       ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_XbbVsQCD                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_XccVsQCD                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_XggVsQCD                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_XqqVsQCD                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_XteVsQCD                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_XtmVsQCD                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_XttVsQCD                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_particleNet_massCorr                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_phi                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_pt                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_rawFactor                                                ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_subJetIdx1                                               ROOT::VecOps::RVec<Short_t>     Dataset
# FatJet_subJetIdx2                                               ROOT::VecOps::RVec<Short_t>     Dataset
# FatJet_tau1                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_tau2                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_tau3                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# FatJet_tau4                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Flag_BadChargedCandidateFilter                                  Bool_t                          Dataset
# Flag_BadChargedCandidateSummer16Filter                          Bool_t                          Dataset
# Flag_BadPFMuonDzFilter                                          Bool_t                          Dataset
# Flag_BadPFMuonFilter                                            Bool_t                          Dataset
# Flag_BadPFMuonSummer16Filter                                    Bool_t                          Dataset
# Flag_CSCTightHalo2015Filter                                     Bool_t                          Dataset
# Flag_CSCTightHaloFilter                                         Bool_t                          Dataset
# Flag_CSCTightHaloTrkMuUnvetoFilter                              Bool_t                          Dataset
# Flag_EcalDeadCellBoundaryEnergyFilter                           Bool_t                          Dataset
# Flag_EcalDeadCellTriggerPrimitiveFilter                         Bool_t                          Dataset
# Flag_HBHENoiseFilter                                            Bool_t                          Dataset
# Flag_HBHENoiseIsoFilter                                         Bool_t                          Dataset
# Flag_HcalStripHaloFilter                                        Bool_t                          Dataset
# Flag_METFilters                                                 Bool_t                          Dataset
# Flag_chargedHadronTrackResolutionFilter                         Bool_t                          Dataset
# Flag_ecalBadCalibFilter                                         Bool_t                          Dataset
# Flag_ecalLaserCorrFilter                                        Bool_t                          Dataset
# Flag_eeBadScFilter                                              Bool_t                          Dataset
# Flag_globalSuperTightHalo2016Filter                             Bool_t                          Dataset
# Flag_globalTightHalo2016Filter                                  Bool_t                          Dataset
# Flag_goodVertices                                               Bool_t                          Dataset
# Flag_hcalLaserEventFilter                                       Bool_t                          Dataset
# Flag_hfNoisyHitsFilter                                          Bool_t                          Dataset
# Flag_muonBadTrackFilter                                         Bool_t                          Dataset
# Flag_trkPOGFilters                                              Bool_t                          Dataset
# Flag_trkPOG_logErrorTooManyClusters                             Bool_t                          Dataset
# Flag_trkPOG_manystripclus53X                                    Bool_t                          Dataset
# Flag_trkPOG_toomanystripclus53X                                 Bool_t                          Dataset
# FsrPhoton_dROverEt2                                             ROOT::VecOps::RVec<Float_t>     Dataset
# FsrPhoton_electronIdx                                           ROOT::VecOps::RVec<Short_t>     Dataset
# FsrPhoton_eta                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# FsrPhoton_muonIdx                                               ROOT::VecOps::RVec<Short_t>     Dataset
# FsrPhoton_phi                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# FsrPhoton_pt                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# FsrPhoton_relIso03                                              ROOT::VecOps::RVec<Float_t>     Dataset
# HLT_CDC_L2cosmic_10_er1p0                                       Bool_t                          Dataset
# HLT_CDC_L2cosmic_5p5_er1p0                                      Bool_t                          Dataset
# HLT_EcalCalibration                                             Bool_t                          Dataset
# HLT_EphemeralZeroBias                                           Bool_t                          Dataset
# HLT_HT300_Beamspot                                              Bool_t                          Dataset
# HLT_HT300_Beamspot_PixelClustersWP2                             Bool_t                          Dataset
# HLT_HT60_Beamspot                                               Bool_t                          Dataset
# HLT_HcalCalibration                                             Bool_t                          Dataset
# HLT_HcalNZS                                                     Bool_t                          Dataset
# HLT_HcalPhiSym                                                  Bool_t                          Dataset
# HLT_IsoTrackHB                                                  Bool_t                          Dataset
# HLT_IsoTrackHE                                                  Bool_t                          Dataset
# HLT_L1SingleMuCosmics_EMTF                                      Bool_t                          Dataset
# HLT_L1_BptxXOR                                                  Bool_t                          Dataset
# HLT_MinimumBiasHF                                               Bool_t                          Dataset
# HLT_PPSMaxTracksPerArm1                                         Bool_t                          Dataset
# HLT_PPSMaxTracksPerRP4                                          Bool_t                          Dataset
# HLT_PPSRandom                                                   Bool_t                          Dataset
# HLT_Physics                                                     Bool_t                          Dataset
# HLT_PixelClusters_WP1                                           Bool_t                          Dataset
# HLT_PixelClusters_WP2                                           Bool_t                          Dataset
# HLT_Random                                                      Bool_t                          Dataset
# HLT_Random_HighRate                                             Bool_t                          Dataset
# HLT_ZeroBias                                                    Bool_t                          Dataset
# HLT_ZeroBias_Alignment                                          Bool_t                          Dataset
# HLT_ZeroBias_Beamspot                                           Bool_t                          Dataset
# HLT_ZeroBias_FirstBXAfterTrain                                  Bool_t                          Dataset
# HLT_ZeroBias_FirstCollisionAfterAbortGap                        Bool_t                          Dataset
# HLT_ZeroBias_FirstCollisionInTrain                              Bool_t                          Dataset
# HLT_ZeroBias_HighExpress                                        Bool_t                          Dataset
# HLT_ZeroBias_IsolatedBunches                                    Bool_t                          Dataset
# HLT_ZeroBias_LastCollisionInTrain                               Bool_t                          Dataset
# HLTriggerFinalPath                                              Bool_t                          Dataset
# HLTriggerFirstPath                                              Bool_t                          Dataset
# IsoTrack_charge                                                 ROOT::VecOps::RVec<Short_t>     Dataset
# IsoTrack_dxy                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_dz                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_eta                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_fromPV                                                 ROOT::VecOps::RVec<Short_t>     Dataset
# IsoTrack_isFromLostTrack                                        ROOT::VecOps::RVec<Bool_t>      Dataset
# IsoTrack_isHighPurityTrack                                      ROOT::VecOps::RVec<Bool_t>      Dataset
# IsoTrack_isPFcand                                               ROOT::VecOps::RVec<Bool_t>      Dataset
# IsoTrack_miniPFRelIso_all                                       ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_miniPFRelIso_chg                                       ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_pdgId                                                  ROOT::VecOps::RVec<Int_t>       Dataset
# IsoTrack_pfRelIso03_all                                         ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_pfRelIso03_chg                                         ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_phi                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# IsoTrack_pt                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_PNetRegPtRawCorr                                            ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_PNetRegPtRawCorrNeutrino                                    ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_PNetRegPtRawRes                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_area                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagDeepFlavB                                               ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagDeepFlavCvB                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagDeepFlavCvL                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagDeepFlavQG                                              ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagPNetB                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagPNetCvB                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagPNetCvL                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagPNetQvG                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagPNetTauVJet                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagRobustParTAK4B                                          ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagRobustParTAK4CvB                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagRobustParTAK4CvL                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_btagRobustParTAK4QG                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_chEmEF                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_chHEF                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_electronIdx1                                                ROOT::VecOps::RVec<Short_t>     Dataset
# Jet_electronIdx2                                                ROOT::VecOps::RVec<Short_t>     Dataset
# Jet_eta                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_hfadjacentEtaStripsSize                                     ROOT::VecOps::RVec<Int_t>       Dataset
# Jet_hfcentralEtaStripSize                                       ROOT::VecOps::RVec<Int_t>       Dataset
# Jet_hfsigmaEtaEta                                               ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_hfsigmaPhiPhi                                               ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_jetId                                                       ROOT::VecOps::RVec<UChar_t>     Dataset
# Jet_mass                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_muEF                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_muonIdx1                                                    ROOT::VecOps::RVec<Short_t>     Dataset
# Jet_muonIdx2                                                    ROOT::VecOps::RVec<Short_t>     Dataset
# Jet_muonSubtrFactor                                             ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_nConstituents                                               ROOT::VecOps::RVec<UChar_t>     Dataset
# Jet_nElectrons                                                  ROOT::VecOps::RVec<UChar_t>     Dataset
# Jet_nMuons                                                      ROOT::VecOps::RVec<UChar_t>     Dataset
# Jet_nSVs                                                        ROOT::VecOps::RVec<UChar_t>     Dataset
# Jet_neEmEF                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_neHEF                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_phi                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_pt                                                          ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_rawFactor                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# Jet_svIdx1                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# Jet_svIdx2                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# L1EG_bx                                                         ROOT::VecOps::RVec<Short_t>     Dataset
# L1EG_eta                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# L1EG_hwIso                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# L1EG_phi                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# L1EG_pt                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# L1EtSum_bx                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# L1EtSum_etSumType                                               ROOT::VecOps::RVec<Int_t>       Dataset
# L1EtSum_phi                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# L1EtSum_pt                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# L1Jet_bx                                                        ROOT::VecOps::RVec<Short_t>     Dataset
# L1Jet_eta                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# L1Jet_phi                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# L1Jet_pt                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# L1Mu_bx                                                         ROOT::VecOps::RVec<Short_t>     Dataset
# L1Mu_eta                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# L1Mu_etaAtVtx                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# L1Mu_hwCharge                                                   ROOT::VecOps::RVec<Short_t>     Dataset
# L1Mu_hwDXY                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# L1Mu_hwQual                                                     ROOT::VecOps::RVec<Int_t>       Dataset
# L1Mu_phi                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# L1Mu_phiAtVtx                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# L1Mu_pt                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# L1Mu_ptUnconstrained                                            ROOT::VecOps::RVec<Float_t>     Dataset
# L1Reco_step                                                     Bool_t                          Dataset
# L1Tau_bx                                                        ROOT::VecOps::RVec<Short_t>     Dataset
# L1Tau_eta                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# L1Tau_hwIso                                                     ROOT::VecOps::RVec<Short_t>     Dataset
# L1Tau_phi                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# L1Tau_pt                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# L1_AlwaysTrue                                                   Bool_t                          Dataset
# L1_BPTX_AND_Ref1_VME                                            Bool_t                          Dataset
# L1_BPTX_AND_Ref3_VME                                            Bool_t                          Dataset
# L1_BPTX_AND_Ref4_VME                                            Bool_t                          Dataset
# L1_BPTX_BeamGas_B1_VME                                          Bool_t                          Dataset
# L1_BPTX_BeamGas_B2_VME                                          Bool_t                          Dataset
# L1_BPTX_BeamGas_Ref1_VME                                        Bool_t                          Dataset
# L1_BPTX_BeamGas_Ref2_VME                                        Bool_t                          Dataset
# L1_BPTX_NotOR_VME                                               Bool_t                          Dataset
# L1_BPTX_OR_Ref3_VME                                             Bool_t                          Dataset
# L1_BPTX_OR_Ref4_VME                                             Bool_t                          Dataset
# L1_BPTX_RefAND_VME                                              Bool_t                          Dataset
# L1_BptxMinus                                                    Bool_t                          Dataset
# L1_BptxOR                                                       Bool_t                          Dataset
# L1_BptxPlus                                                     Bool_t                          Dataset
# L1_BptxXOR                                                      Bool_t                          Dataset
# L1_CDC_SingleMu_3_er1p2_TOP120_DPHI2p618_3p142                  Bool_t                          Dataset
# L1_DoubleEG10_er1p2_dR_Max0p6                                   Bool_t                          Dataset
# L1_DoubleEG10p5_er1p2_dR_Max0p6                                 Bool_t                          Dataset
# L1_DoubleEG11_er1p2_dR_Max0p6                                   Bool_t                          Dataset
# L1_DoubleEG4_er1p2_dR_Max0p9                                    Bool_t                          Dataset
# L1_DoubleEG4p5_er1p2_dR_Max0p9                                  Bool_t                          Dataset
# L1_DoubleEG5_er1p2_dR_Max0p9                                    Bool_t                          Dataset
# L1_DoubleEG5p5_er1p2_dR_Max0p8                                  Bool_t                          Dataset
# L1_DoubleEG6_er1p2_dR_Max0p8                                    Bool_t                          Dataset
# L1_DoubleEG6p5_er1p2_dR_Max0p8                                  Bool_t                          Dataset
# L1_DoubleEG7_er1p2_dR_Max0p8                                    Bool_t                          Dataset
# L1_DoubleEG7p5_er1p2_dR_Max0p7                                  Bool_t                          Dataset
# L1_DoubleEG8_er1p2_dR_Max0p7                                    Bool_t                          Dataset
# L1_DoubleEG8er2p5_HTT260er                                      Bool_t                          Dataset
# L1_DoubleEG8er2p5_HTT280er                                      Bool_t                          Dataset
# L1_DoubleEG8er2p5_HTT300er                                      Bool_t                          Dataset
# L1_DoubleEG8er2p5_HTT320er                                      Bool_t                          Dataset
# L1_DoubleEG8er2p5_HTT340er                                      Bool_t                          Dataset
# L1_DoubleEG8p5_er1p2_dR_Max0p7                                  Bool_t                          Dataset
# L1_DoubleEG9_er1p2_dR_Max0p7                                    Bool_t                          Dataset
# L1_DoubleEG9p5_er1p2_dR_Max0p6                                  Bool_t                          Dataset
# L1_DoubleEG_15_10_er2p5                                         Bool_t                          Dataset
# L1_DoubleEG_20_10_er2p5                                         Bool_t                          Dataset
# L1_DoubleEG_22_10_er2p5                                         Bool_t                          Dataset
# L1_DoubleEG_25_12_er2p5                                         Bool_t                          Dataset
# L1_DoubleEG_25_14_er2p5                                         Bool_t                          Dataset
# L1_DoubleEG_27_14_er2p5                                         Bool_t                          Dataset
# L1_DoubleEG_LooseIso16_LooseIso12_er1p5                         Bool_t                          Dataset
# L1_DoubleEG_LooseIso18_LooseIso12_er1p5                         Bool_t                          Dataset
# L1_DoubleEG_LooseIso20_LooseIso12_er1p5                         Bool_t                          Dataset
# L1_DoubleEG_LooseIso22_12_er2p5                                 Bool_t                          Dataset
# L1_DoubleEG_LooseIso22_LooseIso12_er1p5                         Bool_t                          Dataset
# L1_DoubleEG_LooseIso25_12_er2p5                                 Bool_t                          Dataset
# L1_DoubleEG_LooseIso25_LooseIso12_er1p5                         Bool_t                          Dataset
# L1_DoubleIsoTau26er2p1_Jet55_RmOvlp_dR0p5                       Bool_t                          Dataset
# L1_DoubleIsoTau26er2p1_Jet70_RmOvlp_dR0p5                       Bool_t                          Dataset
# L1_DoubleIsoTau28er2p1                                          Bool_t                          Dataset
# L1_DoubleIsoTau28er2p1_Mass_Max80                               Bool_t                          Dataset
# L1_DoubleIsoTau28er2p1_Mass_Max90                               Bool_t                          Dataset
# L1_DoubleIsoTau30er2p1                                          Bool_t                          Dataset
# L1_DoubleIsoTau30er2p1_Mass_Max80                               Bool_t                          Dataset
# L1_DoubleIsoTau30er2p1_Mass_Max90                               Bool_t                          Dataset
# L1_DoubleIsoTau32er2p1                                          Bool_t                          Dataset
# L1_DoubleIsoTau32er2p1_Mass_Max80                               Bool_t                          Dataset
# L1_DoubleIsoTau34er2p1                                          Bool_t                          Dataset
# L1_DoubleIsoTau35er2p1                                          Bool_t                          Dataset
# L1_DoubleIsoTau36er2p1                                          Bool_t                          Dataset
# L1_DoubleJet100er2p3_dEta_Max1p6                                Bool_t                          Dataset
# L1_DoubleJet100er2p5                                            Bool_t                          Dataset
# L1_DoubleJet112er2p3_dEta_Max1p6                                Bool_t                          Dataset
# L1_DoubleJet120er2p5                                            Bool_t                          Dataset
# L1_DoubleJet120er2p5_Mu3_dR_Max0p8                              Bool_t                          Dataset
# L1_DoubleJet150er2p5                                            Bool_t                          Dataset
# L1_DoubleJet16er2p5_Mu3_dR_Max0p4                               Bool_t                          Dataset
# L1_DoubleJet30er2p5_Mass_Min225_dEta_Max1p5                     Bool_t                          Dataset
# L1_DoubleJet30er2p5_Mass_Min250_dEta_Max1p5                     Bool_t                          Dataset
# L1_DoubleJet30er2p5_Mass_Min300_dEta_Max1p5                     Bool_t                          Dataset
# L1_DoubleJet30er2p5_Mass_Min330_dEta_Max1p5                     Bool_t                          Dataset
# L1_DoubleJet30er2p5_Mass_Min360_dEta_Max1p5                     Bool_t                          Dataset
# L1_DoubleJet35_Mass_Min450_IsoTau45_RmOvlp                      Bool_t                          Dataset
# L1_DoubleJet35_Mass_Min450_IsoTau45er2p1_RmOvlp_dR0p5           Bool_t                          Dataset
# L1_DoubleJet35er2p5_Mu3_dR_Max0p4                               Bool_t                          Dataset
# L1_DoubleJet40_Mass_Min450_IsoEG10er2p1_RmOvlp_dR0p2            Bool_t                          Dataset
# L1_DoubleJet40_Mass_Min450_LooseIsoEG15er2p1_RmOvlp_dR0p2       Bool_t                          Dataset
# L1_DoubleJet40er2p5                                             Bool_t                          Dataset
# L1_DoubleJet45_Mass_Min450_IsoTau45er2p1_RmOvlp_dR0p5           Bool_t                          Dataset
# L1_DoubleJet45_Mass_Min450_LooseIsoEG20er2p1_RmOvlp_dR0p2       Bool_t                          Dataset
# L1_DoubleJet60er2p5_Mu3_dR_Max0p4                               Bool_t                          Dataset
# L1_DoubleJet80er2p5_Mu3_dR_Max0p4                               Bool_t                          Dataset
# L1_DoubleJet_100_30_DoubleJet30_Mass_Min620                     Bool_t                          Dataset
# L1_DoubleJet_100_30_DoubleJet30_Mass_Min800                     Bool_t                          Dataset
# L1_DoubleJet_110_35_DoubleJet35_Mass_Min620                     Bool_t                          Dataset
# L1_DoubleJet_110_35_DoubleJet35_Mass_Min800                     Bool_t                          Dataset
# L1_DoubleJet_115_40_DoubleJet40_Mass_Min620                     Bool_t                          Dataset
# L1_DoubleJet_115_40_DoubleJet40_Mass_Min620_Jet60TT28           Bool_t                          Dataset
# L1_DoubleJet_120_45_DoubleJet45_Mass_Min620                     Bool_t                          Dataset
# L1_DoubleJet_120_45_DoubleJet45_Mass_Min620_Jet60TT28           Bool_t                          Dataset
# L1_DoubleJet_60_30_DoubleJet30_Mass_Min500_DoubleJetCentral50   Bool_t                          Dataset
# L1_DoubleJet_65_30_DoubleJet30_Mass_Min400_ETMHF65              Bool_t                          Dataset
# L1_DoubleJet_65_35_DoubleJet35_Mass_Min500_DoubleJetCentral50   Bool_t                          Dataset
# L1_DoubleJet_70_35_DoubleJet35_Mass_Min400_ETMHF65              Bool_t                          Dataset
# L1_DoubleJet_80_30_DoubleJet30_Mass_Min500_Mu3OQ                Bool_t                          Dataset
# L1_DoubleJet_80_30_Mass_Min420_DoubleMu0_SQ                     Bool_t                          Dataset
# L1_DoubleJet_80_30_Mass_Min420_IsoTau40_RmOvlp                  Bool_t                          Dataset
# L1_DoubleJet_80_30_Mass_Min420_Mu8                              Bool_t                          Dataset
# L1_DoubleJet_85_35_DoubleJet35_Mass_Min500_Mu3OQ                Bool_t                          Dataset
# L1_DoubleJet_90_30_DoubleJet30_Mass_Min620                      Bool_t                          Dataset
# L1_DoubleJet_90_30_DoubleJet30_Mass_Min800                      Bool_t                          Dataset
# L1_DoubleLLPJet40                                               Bool_t                          Dataset
# L1_DoubleLooseIsoEG22er2p1                                      Bool_t                          Dataset
# L1_DoubleLooseIsoEG24er2p1                                      Bool_t                          Dataset
# L1_DoubleMu0                                                    Bool_t                          Dataset
# L1_DoubleMu0_Mass_Min1                                          Bool_t                          Dataset
# L1_DoubleMu0_OQ                                                 Bool_t                          Dataset
# L1_DoubleMu0_SQ                                                 Bool_t                          Dataset
# L1_DoubleMu0_SQ_OS                                              Bool_t                          Dataset
# L1_DoubleMu0_Upt15_Upt7                                         Bool_t                          Dataset
# L1_DoubleMu0_Upt15_Upt7_BMTF_EMTF                               Bool_t                          Dataset
# L1_DoubleMu0_Upt5_Upt5                                          Bool_t                          Dataset
# L1_DoubleMu0_Upt5_Upt5_BMTF_EMTF                                Bool_t                          Dataset
# L1_DoubleMu0_Upt6_IP_Min1_Upt4                                  Bool_t                          Dataset
# L1_DoubleMu0_Upt6_IP_Min1_Upt4_BMTF_EMTF                        Bool_t                          Dataset
# L1_DoubleMu0_dR_Max1p6_Jet90er2p5_dR_Max0p8                     Bool_t                          Dataset
# L1_DoubleMu0er1p4_OQ_OS_dEta_Max1p6                             Bool_t                          Dataset
# L1_DoubleMu0er1p4_SQ_OS_dEta_Max1p2                             Bool_t                          Dataset
# L1_DoubleMu0er1p4_SQ_OS_dR_Max1p4                               Bool_t                          Dataset
# L1_DoubleMu0er1p5_SQ                                            Bool_t                          Dataset
# L1_DoubleMu0er1p5_SQ_OS                                         Bool_t                          Dataset
# L1_DoubleMu0er1p5_SQ_OS_dEta_Max1p2                             Bool_t                          Dataset
# L1_DoubleMu0er1p5_SQ_OS_dR_Max1p4                               Bool_t                          Dataset
# L1_DoubleMu0er1p5_SQ_dR_Max1p4                                  Bool_t                          Dataset
# L1_DoubleMu0er2p0_SQ_OS_dEta_Max1p5                             Bool_t                          Dataset
# ...
# SV_charge                                                       ROOT::VecOps::RVec<Short_t>     Dataset
# SV_chi2                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# SV_dlen                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# SV_dlenSig                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# SV_dxy                                                          ROOT::VecOps::RVec<Float_t>     Dataset
# SV_dxySig                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# SV_eta                                                          ROOT::VecOps::RVec<Float_t>     Dataset
# SV_mass                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# SV_ndof                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# SV_ntracks                                                      ROOT::VecOps::RVec<UChar_t>     Dataset
# SV_pAngle                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# SV_phi                                                          ROOT::VecOps::RVec<Float_t>     Dataset
# SV_pt                                                           ROOT::VecOps::RVec<Float_t>     Dataset
# SV_x                                                            ROOT::VecOps::RVec<Float_t>     Dataset
# SV_y                                                            ROOT::VecOps::RVec<Float_t>     Dataset
# SV_z                                                            ROOT::VecOps::RVec<Float_t>     Dataset
# SoftActivityJetHT                                               Float_t                         Dataset
# SoftActivityJetHT10                                             Float_t                         Dataset
# SoftActivityJetHT2                                              Float_t                         Dataset
# SoftActivityJetHT5                                              Float_t                         Dataset
# SoftActivityJetNjets10                                          Int_t                           Dataset
# SoftActivityJetNjets2                                           Int_t                           Dataset
# SoftActivityJetNjets5                                           Int_t                           Dataset
# SoftActivityJet_eta                                             ROOT::VecOps::RVec<Float_t>     Dataset
# SoftActivityJet_phi                                             ROOT::VecOps::RVec<Float_t>     Dataset
# SoftActivityJet_pt                                              ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_btagDeepB                                                ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_eta                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_mass                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_n2b1                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_n3b1                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_phi                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_pt                                                       ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_rawFactor                                                ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_tau1                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_tau2                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_tau3                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# SubJet_tau4                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_charge                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# Tau_chargedIso                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_decayMode                                                   ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_decayModePNet                                               ROOT::VecOps::RVec<Short_t>     Dataset
# Tau_dxy                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_dz                                                          ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_eleIdx                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# Tau_eta                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_idAntiEleDeadECal                                           ROOT::VecOps::RVec<Bool_t>      Dataset
# Tau_idAntiMu                                                    ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_idDecayModeNewDMs                                           ROOT::VecOps::RVec<Bool_t>      Dataset
# Tau_idDecayModeOldDMs                                           ROOT::VecOps::RVec<Bool_t>      Dataset
# Tau_idDeepTau2017v2p1VSe                                        ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_idDeepTau2017v2p1VSjet                                      ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_idDeepTau2017v2p1VSmu                                       ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_idDeepTau2018v2p5VSe                                        ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_idDeepTau2018v2p5VSjet                                      ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_idDeepTau2018v2p5VSmu                                       ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_jetIdx                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# Tau_leadTkDeltaEta                                              ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_leadTkDeltaPhi                                              ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_leadTkPtOverTauPt                                           ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_mass                                                        ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_muIdx                                                       ROOT::VecOps::RVec<Short_t>     Dataset
# Tau_nSVs                                                        ROOT::VecOps::RVec<UChar_t>     Dataset
# Tau_neutralIso                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_phi                                                         ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_photonsOutsideSignalCone                                    ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_probDM0PNet                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_probDM10PNet                                                ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_probDM11PNet                                                ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_probDM1PNet                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_probDM2PNet                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_pt                                                          ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_ptCorrPNet                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_puCorr                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_qConfPNet                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawDeepTau2017v2p1VSe                                       ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawDeepTau2017v2p1VSjet                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawDeepTau2017v2p1VSmu                                      ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawDeepTau2018v2p5VSe                                       ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawDeepTau2018v2p5VSjet                                     ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawDeepTau2018v2p5VSmu                                      ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawIso                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawIsodR03                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawPNetVSe                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawPNetVSjet                                                ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_rawPNetVSmu                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# Tau_svIdx1                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# Tau_svIdx2                                                      ROOT::VecOps::RVec<Short_t>     Dataset
# TkMET_phi                                                       Float_t                         Dataset
# TkMET_pt                                                        Float_t                         Dataset
# TkMET_sumEt                                                     Float_t                         Dataset
# TrigObj_eta                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# TrigObj_filterBits                                              ROOT::VecOps::RVec<Int_t>       Dataset
# TrigObj_id                                                      ROOT::VecOps::RVec<UShort_t>    Dataset
# TrigObj_l1charge                                                ROOT::VecOps::RVec<Short_t>     Dataset
# TrigObj_l1iso                                                   ROOT::VecOps::RVec<Int_t>       Dataset
# TrigObj_l1pt                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# TrigObj_l1pt_2                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# TrigObj_l2pt                                                    ROOT::VecOps::RVec<Float_t>     Dataset
# TrigObj_phi                                                     ROOT::VecOps::RVec<Float_t>     Dataset
# TrigObj_pt                                                      ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_charge                                               ROOT::VecOps::RVec<Int_t>       Dataset
# boostedTau_chargedIso                                           ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_decayMode                                            ROOT::VecOps::RVec<Int_t>       Dataset
# boostedTau_eta                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_idAntiEle2018                                        ROOT::VecOps::RVec<UChar_t>     Dataset
# boostedTau_idAntiMu                                             ROOT::VecOps::RVec<UChar_t>     Dataset
# boostedTau_idMVAnewDM2017v2                                     ROOT::VecOps::RVec<UChar_t>     Dataset
# boostedTau_idMVAoldDM2017v2                                     ROOT::VecOps::RVec<UChar_t>     Dataset
# boostedTau_jetIdx                                               ROOT::VecOps::RVec<Short_t>     Dataset
# boostedTau_leadTkDeltaEta                                       ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_leadTkDeltaPhi                                       ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_leadTkPtOverTauPt                                    ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_mass                                                 ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_neutralIso                                           ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_phi                                                  ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_photonsOutsideSignalCone                             ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_pt                                                   ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_puCorr                                               ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_rawAntiEle2018                                       ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_rawAntiEleCat2018                                    ROOT::VecOps::RVec<Short_t>     Dataset
# boostedTau_rawIso                                               ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_rawIsodR03                                           ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_rawMVAnewDM2017v2                                    ROOT::VecOps::RVec<Float_t>     Dataset
# boostedTau_rawMVAoldDM2017v2                                    ROOT::VecOps::RVec<Float_t>     Dataset
# bunchCrossing                                                   UInt_t                          Dataset
# event                                                           ULong64_t                       Dataset
# luminosityBlock                                                 UInt_t                          Dataset
# nCorrT1METJet                                                   Int_t                           Dataset
# nElectron                                                       Int_t                           Dataset
# nFatJet                                                         Int_t                           Dataset
# nFsrPhoton                                                      Int_t                           Dataset
# nIsoTrack                                                       Int_t                           Dataset
# nJet                                                            Int_t                           Dataset
# nL1EG                                                           Int_t                           Dataset
# nL1EtSum                                                        Int_t                           Dataset
# nL1Jet                                                          Int_t                           Dataset
# nL1Mu                                                           Int_t                           Dataset
# nL1Tau                                                          Int_t                           Dataset
# nLowPtElectron                                                  Int_t                           Dataset
# nMuon                                                           Int_t                           Dataset
# nOtherPV                                                        Int_t                           Dataset
# nPPSLocalTrack                                                  Int_t                           Dataset
# nPhoton                                                         Int_t                           Dataset
# nProton_multiRP                                                 Int_t                           Dataset
# nProton_singleRP                                                Int_t                           Dataset
# nSV                                                             Int_t                           Dataset
# nSoftActivityJet                                                Int_t                           Dataset
# nSubJet                                                         Int_t                           Dataset
# nTau                                                            Int_t                           Dataset
# nTrigObj                                                        Int_t                           Dataset
# nboostedTau                                                     Int_t                           Dataset
# run                                                             UInt_t                          Dataset

# %% [markdown]
# ## Filtering, defining new columns and saving the RDF
#
# Now that's a unit of an RDF. Let's do the same dijet cuts to it as before to get rid of some events.
#
# For reference, the cuts are
# - require at least two jets
# - one in barrel ($|\eta | < 1.3$)
# - if there's a third jet it should have pt less than 0.2 of the average of the dijet systems pt.
#
# Let's also define some new columns that we'd be interested to share in the `.root` file.

# %%
alpha = 0.2
eta_cut = 1.3

df = (df.Filter("nJet >= 2", "Require at least 2 jets")
        .Filter(f"abs(Jet_eta[0]) < {eta_cut} || abs(Jet_eta[1]) < {eta_cut}", f"Require one of the leading jets in the abs(eta) < {eta_cut} region")
        .Filter(f"nJet > 2 ? Jet_pt[2] / (0.5 * (Jet_pt[0] + Jet_pt[1])) < {alpha} : true", f"Third jets pt should be less than {alpha} of the dijet average pt")
        .Define("Jet_leading", "Jet_pt[0]")
        .Define("Jet_trailing", "Jet_pt[1]")
)

# %% [markdown]
# Let's see the effect:

# %%
df.Report().Print()
# Out:
# Require at least 2 jets: pass=1657932    all=7285827    -- eff=22.76 % cumulative eff=22.76 %
# Require one of the leading jets in the abs(eta) < 1.3 region: pass=1011727    all=1657932    -- eff=61.02 % cumulative eff=13.89 %
# Third jets pt should be less than 0.2 of the dijet average pt: pass=647699     all=1011727    -- eff=64.02 % cumulative eff=8.89 %

# %% [markdown]
# Just ~9 % of the original events left, which sounds good for our skim.
#
# Now let's save this RDF to a file, but let's also limit the columns to just have the "Jet_" ones.

# %%
jet_cols = [str(s) for s in df.GetColumnNames() if str(s).startswith("Jet_")] # The str() is here to go from string datatype to Python's default datatype str

# %% [markdown]
# Saving an RDF happens with `.Snapshot()`. You should see the [documentation](https://root.cern/doc/master/classROOT_1_1RDF_1_1RInterface.html#ac5903d3acec8c52f13cbd405371f7fb7) for further details on topics such as compression.
#
# Snapshot can be quite slow, especially with larger RDFs. This can be made faster by choosing less columns and creating harder filters.

# %%
df.Snapshot(tree, "dijetFromZB.root", jet_cols)
# Out:
# <cppyy.gbl.ROOT.RDF.RResultPtr<ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void> > object at 0xd6f53f0>
